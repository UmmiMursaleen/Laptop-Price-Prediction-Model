# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\Dell\Desktop\Pandas\Datasets\movies_complete.csv')

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
pd.set_option('display.max_columns',30)

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# df.info(),
# df.describe(),
# df.head(),
# df.tail(),
# df.unique(),
# df.columns,
# df.isna(),

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.describe()
# Out:
#                   id  budget_musd  revenue_musd    vote_count  vote_average  \
# count   44691.000000  8854.000000   7385.000000  44691.000000  42077.000000
# mean   107186.242845    21.669886     68.968649    111.653778      6.003341
# std    111806.362236    34.359837    146.608966    495.322313      1.281060
# min         2.000000     0.000001      0.000001      0.000000      0.000000
# 25%     26033.500000     2.000000      2.405420      3.000000      5.300000
# 50%     59110.000000     8.200000     16.872671     10.000000      6.100000
# 75%    154251.000000    25.000000     67.642693     35.000000      6.800000
# max    469172.000000   380.000000   2787.965087  14075.000000     10.000000
#
#          popularity       runtime     cast_size     crew_size
# count  44691.000000  43179.000000  44691.000000  44691.000000
# mean       2.957460     97.566850     12.479090     10.313643
# std        6.040008     34.653409     12.124663     15.892154
# ...

# %%
df.describe(include='object')
# Out:
#              title                 tagline release_date genres  \
# count        44691                   20284        44657  42586
# unique       41605                   20171        17225   4044
# top     Cinderella  Based on a true story.   2008-01-01  Drama
# freq            11                       7          133   4935
#
#        belongs_to_collection original_language       production_companies  \
# count                   4463             44681                      33356
# unique                  1691                89                      22537
# top          The Bowery Boys                en  Metro-Goldwyn-Mayer (MGM)
# freq                      29             31755                        741
#
#             production_countries                              overview  \
# count                      38835                                 43740
# unique                      2377                                 43715
# ...

# %%
df.head(10)
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
# 5    949                         Heat
# 6  11860                      Sabrina
# 7  45325                 Tom and Huck
# 8   9091                 Sudden Death
# 9    710                    GoldenEye
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
# 5                           A Los Angeles Crime Saga   1995-12-15
# 6  You are cordially invited to the most surprisi...   1995-12-15
# ...

# %%
df.tail(10)
# Out:
#            id                      title  \
# 44681   84419           House of Horrors
# 44682  390959  Shadow of the Blair Witch
# 44683  289923        The Burkittsville 7
# 44684  222848            Caged Heat 3000
# 44685   30840                 Robin Hood
# 44686  439050                     Subdue
# 44687  111109        Century of Birthing
# 44688   67758                   Betrayal
# 44689  227506           Satan Triumphant
# 44690  461257                   Queerama
#
#                                                  tagline release_date  \
# 44681                                Meet...The CREEPER!   1946-03-29
# 44682                                                NaN   2000-10-22
# 44683  Do you know what happened 50 years before "The...   2000-10-03
# 44684                                                NaN   1995-01-01
# 44685                                                NaN   1991-05-13
# 44686         Rising and falling between a man and woman          NaN
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# title                        0
# tagline                  24407
# release_date                34
# genres                    2105
# belongs_to_collection    40228
# original_language           10
# budget_musd              35837
# revenue_musd             37306
# production_companies     11335
# production_countries      5856
# vote_count                   0
# vote_average              2614
# popularity                   0
# runtime                   1512
# overview                   951
# spoken_languages          3597
# poster_path                224
# cast                      2189
# cast_size                    0
# crew_size                    0
# director                   731
# dtype: int64

# %%
df.duplicated('id').sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df=df[[
    'id', 'title', 'release_date', 'genres',
       'belongs_to_collection', 'budget_musd',
       'revenue_musd', 'production_companies', 'production_countries',
       'vote_count', 'vote_average', 'popularity', 'runtime', 'poster_path',
       'director'
]]

# %%
df
# Out:
#            id                        title release_date  \
# 0         862                    Toy Story   1995-10-30
# 1        8844                      Jumanji   1995-12-15
# 2       15602             Grumpier Old Men   1995-12-22
# 3       31357            Waiting to Exhale   1995-12-22
# 4       11862  Father of the Bride Part II   1995-02-10
# ...       ...                          ...          ...
# 44686  439050                       Subdue          NaN
# 44687  111109          Century of Birthing   2011-11-17
# 44688   67758                     Betrayal   2003-08-01
# 44689  227506             Satan Triumphant   1917-10-21
# 44690  461257                     Queerama   2017-06-09
#
#                          genres           belongs_to_collection  budget_musd  \
# 0       Animation|Comedy|Family            Toy Story Collection         30.0
# 1      Adventure|Fantasy|Family                             NaN         65.0
# ...

# %%
df['release_date']=pd.to_datetime(df['release_date'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_420\642638228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['release_date']=pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   release_date           44657 non-null  datetime64[ns]
#  3   genres                 42586 non-null  object
#  4   belongs_to_collection  4463 non-null   object
#  5   budget_musd            8854 non-null   float64
#  6   revenue_musd           7385 non-null   float64
#  7   production_companies   33356 non-null  object
#  8   production_countries   38835 non-null  object
#  9   vote_count             44691 non-null  float64
#  10  vote_average           42077 non-null  float64
#  11  popularity             44691 non-null  float64
#  12  runtime                43179 non-null  float64
#  13  poster_path            44467 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# id                           0
# title                        0
# release_date                34
# genres                    2105
# belongs_to_collection    40228
# budget_musd              35837
# revenue_musd             37306
# production_companies     11335
# production_countries      5856
# vote_count                   0
# vote_average              2614
# popularity                   0
# runtime                   1512
# poster_path                224
# director                   731
# dtype: int64

# %%
df['runtime']
# Out:
# 0         81.0
# 1        104.0
# 2        101.0
# 3        127.0
# 4        106.0
#          ...
# 44686     90.0
# 44687    360.0
# 44688     90.0
# 44689     87.0
# 44690     75.0
# Name: runtime, Length: 44691, dtype: float64

# %%
df=df.drop(['production_companies', 'production_countries'],axis=1)

# %%
df
# Out:
#            id                        title release_date  \
# 0         862                    Toy Story   1995-10-30
# 1        8844                      Jumanji   1995-12-15
# 2       15602             Grumpier Old Men   1995-12-22
# 3       31357            Waiting to Exhale   1995-12-22
# 4       11862  Father of the Bride Part II   1995-02-10
# ...       ...                          ...          ...
# 44686  439050                       Subdue          NaT
# 44687  111109          Century of Birthing   2011-11-17
# 44688   67758                     Betrayal   2003-08-01
# 44689  227506             Satan Triumphant   1917-10-21
# 44690  461257                     Queerama   2017-06-09
#
#                          genres           belongs_to_collection  budget_musd  \
# 0       Animation|Comedy|Family            Toy Story Collection         30.0
# 1      Adventure|Fantasy|Family                             NaN         65.0
# ...

# %%
df['release_date'].max()
# Out:
# Timestamp('2017-12-27 00:00:00')

# %%
df.query("title == 'Cinderella'")
# Out:
#            id       title release_date                                 genres  \
# 984     11224  Cinderella   1950-03-04       Family|Fantasy|Animation|Romance
# 12988   42884  Cinderella   1997-11-02  TV Movie|Family|Fantasy|Music|Romance
# 23254   92349  Cinderella   1914-12-28                          Fantasy|Drama
# 23265  105875  Cinderella   2002-08-06               Animation|Family|Fantasy
# 28073  261985  Cinderella   2011-10-30                        Family|TV Movie
# 28340  150689  Cinderella   2015-03-12           Romance|Fantasy|Family|Drama
# 33805   42651  Cinderella   1947-11-28                  Comedy|Family|Fantasy
# 35114   44459  Cinderella   1957-03-31                          Drama|Romance
# 35116  289673  Cinderella   2000-01-01                                    NaN
# 40439  114108  Cinderella   1899-10-01  Fantasy|Horror|Science Fiction|Family
# 44633   98604  Cinderella   2012-02-14                         Comedy|Romance
#
# ...

# %%
df['title'].value_counts().head(10)
# Out:
# title
# Cinderella              11
# Alice in Wonderland      9
# Hamlet                   9
# Beauty and the Beast     8
# Les Misérables           8
# The Three Musketeers     7
# A Christmas Carol        7
# Treasure Island          7
# Home                     6
# Jane Eyre                6
# Name: count, dtype: int64

# %%
from IPython.display import HTML

# %%
df['year']=df['release_date'].dt.year
